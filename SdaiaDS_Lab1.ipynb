# %% [markdown]
# <a href="https://colab.research.google.com/github/norahalsuwailem/SDAIA-Data-Visualization/blob/main/SdaiaDS_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
   "Region": ["Riyadh", "Makkah", "Madinah", "Eastern", "Qassim"],
   "Adoption": [85, 72, 91, 65, 78]
}

df = pd.DataFrame(data)

df
# Out:
#     Region  Adoption
# 0   Riyadh        85
# 1   Makkah        72
# 2  Madinah        91
# 3  Eastern        65
# 4   Qassim        78

# %%
df_sorted = df.sort_values("Adoption")

plt.figure(figsize=(8,5))
plt.bar(df_sorted["Region"], df_sorted["Adoption"])
plt.xlabel("Region")
plt.ylabel("Adoption (%)")
plt.title("Digital Adoption by Region — Sorted")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(df["Region"], df["Adoption"])
plt.xlabel("Region")
plt.ylabel("Adoption (%)")
plt.title("Digital Adoption by Region — Unsorted")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(7,7))

plt.pie(
   df["Adoption"],
   labels=df["Region"],
   autopct="%1.1f%%"
)

plt.title("Digital Adoption by Region — Pie")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(
   df["Region"],
   df["Adoption"],
   s=df["Adoption"] * 20
)

plt.xlabel("Region")
plt.ylabel("Adoption (%)")
plt.title("Digital Adoption by Region — Bubble")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,2))

sns.heatmap(
   [df["Adoption"]],
   annot=True,
   xticklabels=df["Region"],
   yticklabels=["Adoption"],
   cmap="Blues"
)

plt.title("Digital Adoption by Region — Heatmap")
plt.show()
