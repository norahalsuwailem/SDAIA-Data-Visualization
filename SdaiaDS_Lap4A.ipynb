# %% [markdown]
# <a href="https://colab.research.google.com/github/norahalsuwailem/SDAIA-Data-Visualization/blob/main/SdaiaDS_Lap4A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Indicator(
   mode="number",
   value=8,
   number={"suffix": "%"},
   title={"text": "Overall Absence"}
))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
absence = [5, 6, 7, 8, 9, 8]

fig = go.Figure()

fig.add_trace(go.Scatter(
   x=months,
   y=absence,
   mode="lines+markers"
))

fig.update_layout(
   title="Monthly Absence Trend",
   xaxis_title="Month",
   yaxis_title="Absence (%)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

departments = ["HR", "Finance", "IT", "Sales"]
absence = [5, 8, 12, 7]

fig = px.bar(
   x=departments,
   y=absence,
   labels={"x": "Department", "y": "Absence (%)"},
   title="Absence by Department"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
employees = [100, 100, 100, 100]
absent = [5, 8, 12, 7]

total_absent = sum(absent)
total_employees = sum(employees)

rate = total_absent / total_employees * 100

print("Total absent:", total_absent)
print("Total employees:", total_employees)
print("Correct absence rate:", rate, "%")
# Out:
# Total absent: 32
# Total employees: 400
# Correct absence rate: 8.0 %

# %%
target = 5
current = 8

print("Current:", current, "%")
print("Target:", target, "%")

if current > target:
   print("Above target")
else:
   print("Within target")
# Out:
# Current: 8 %
# Target: 5 %
# Above target

# %%
# Dashboard title:
title = "Employee Absence is Above Target — 8% vs 5%"
print(title)
# Out:
# Employee Absence is Above Target — 8% vs 5%

# %%
fig.write_html("employee_absence_dashboard.html")

print("Dashboard exported successfully.")
# Out:
# Dashboard exported successfully.
